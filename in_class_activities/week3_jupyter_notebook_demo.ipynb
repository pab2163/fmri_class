# %% [markdown]
# # Jupyter Notebook Demo
#
# This is a **markdown** chunk.
# * Great for headers, notes, lists, etc

# %%
# code chunk
from nilearn import datasets, plotting
plotting.plot_img(datasets.load_mni152_template())

# %%
# notice what gets printed out here
2+5
2+2
# Out:
# 4

# %% [markdown]
# # Another header
#
# ## Subheader

# %%
# notice what gets printed out here
print(2+5)
print(2+2)
# Out:
# 7
# 4
